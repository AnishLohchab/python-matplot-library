# %% [markdown]
# the kind of plot to produce :
#     'line' : line plot(default)
#     'bar'  : vertical bar plot
#     'hist' :horizontal bar plot
#     'box'  : histogram
#     'kde'  : kernal density estimation plot
#     'density': same as 'kde'      #to give as a simple line chart to verify whether it is a skewed on not.
#     'area' : area of plot
#     'pie' : pie plot
#     'scatter': scatter plot(Data frame only)
#     'hexbin': hexbin plot(Data frame only)

# %%
# %matplotlin inline          #it is like an magic command to give an image or in chart form.
# Out:
# UsageError: Line magic function `%matplotlin` not found.

# %% [markdown]
# #matplotlib is library for visualization

# %% [markdown]
# # Line chart(default)

# %%
import pandas as pd
import matplotlib.pyplot as plt     #Most of the Matplotlib utilities lies under the pyplot submodule, and are usually imported under the plt alias

df = pd.read_csv(r"C:\Users\Anish\Downloads\Salaries.csv")

df.plot()

plt.show()     #its upto you whether you use or you can't. it is mainly uses in matplotlib.

#here only phd,service and salary is use bcz they have an nu erical data.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\Anish\Downloads\Salaries.csv")

df['salary'].plot()

plt.show()

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\Anish\Downloads\Salaries.csv")

df['phd'].plot()

plt.show()

# %% [markdown]
# # Scatter chart

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv(r"C:\Users\Anish\Downloads\Salaries.csv")

df.plot(kind = 'scatter', x ='phd' , y ='salary')     #kind is used to describe which chart is going to plot.

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv(r"C:\Users\Anish\Downloads\Salaries.csv")

df.plot(kind = 'scatter', x ='service' , y ='salary')

plt.show()

# %% [markdown]
# # Histogram:distibution of data

# %%
df['salary'].plot(kind = 'hist')      #histogram gives the distribution of data
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['service'].plot(kind = 'hist')       # 2 mode values bcz having two peaks
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['phd'].plot(kind = 'hist')          #right skewed
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['rank'].value_counts()
# Out:
# Prof         46
# AsstProf     19
# AssocProf    13
# Name: rank, dtype: int64

# %% [markdown]
# # Bar and barh chart

# %%
import pandas as pd
import matplotlib.pyplot as plt

## -------Group by

Rank_totals = df.groupby('rank')['salary'].sum().sort_values()
Rank_totals.plot(kind = 'bar')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

## -------Group by

Rank_totals = df.groupby('rank')['salary'].sum().sort_values(ascending = False)         #groupby function to group
Rank_totals.plot(kind = 'bar')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

## -------Group by

Rank_totals = df.groupby('rank')['salary'].sum().sort_values(ascending = False)         #groupby function to group
Rank_totals.plot(kind = 'barh')             #barh for horizontal bars

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

## -------Group by

Rank_totals = df.groupby('rank')['salary'].sum().sort_values(ascending = True)         #groupby function to group
Rank_totals.plot(kind = 'barh')             #barh for horizontal bars

plt.show()

# %% [markdown]
# # Pie chart

# %%
Rank_totals.plot(kind = 'pie')
# Out:
# <Axes: ylabel='salary'>

# %%
df.plot.pie(y = 'service')
# Out:
# <Axes: ylabel='service'>

# %%
Rank_totals.plot.pie()
# Out:
# <Axes: ylabel='salary'>

# %% [markdown]
# # Box plot

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\Anish\Downloads\Salaries.csv")

df.plot(kind = 'box' , x = 'service',y = 'salary')

plt.show()                               #right skewed -> bcz hum box m dekhenge toh have minimum space at the loweer side so it it is right skewed.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\Anish\Downloads\Salaries.csv")

df.plot(kind = 'box' )

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\Anish\Downloads\Salaries.csv")

df[['phd','service']].plot(kind = 'box')

plt.show()

# %% [markdown]
# # Area plot

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\Anish\Downloads\Salaries.csv")

df['salary'].plot(kind = 'area')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\Anish\Downloads\Salaries.csv")

df['phd'].plot(kind = 'area')

plt.show()

# %% [markdown]
# # Kde plot

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\Anish\Downloads\Salaries.csv")

df['salary'].plot(kind = 'kde')               #kernel density function

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\Anish\Downloads\Salaries.csv")

df['service'].plot(kind = 'kde')               #kernel density function

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\Anish\Downloads\Salaries.csv")

df[['phd','service']].plot(kind = 'kde')               #kernel density function

plt.show()

# %% [markdown]
# # Haxabin plot

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\Anish\Downloads\Salaries.csv")

df.plot(kind = 'hexbin', x = 'service' , y = 'salary')  #kernel density function

plt.show()

# %% [markdown]
# x and y parameter specify the values that you want on the x and y column.
# figsize: specifies the size of the figure object.
# Title: to b e used for the plot.
# legend: to be placed on axis subplots.
# Style: the matplotlib line style per column.
# x and y label: name to use the label on x axis and y axis.
# subplots: make seperate subplots for each column.
# kind: the kind plot produce. we will look this parameter in detail in the upcoming in the upcoming sections.

# %%
df.plot(y = 'salary' , figsize = (10,6),title = 'salary and service info',ylabel='salary in rupees',xlabel = 'salary count');

# %%
df.plot(kind ='scatter',x = 'service',y = 'salary' , figsize = (6,6),title = 'salary and service info',ylabel='salary in rupees',xlabel = 'salary count');

# %%
Rank_totals = df.groupby('rank')[['service','phd']].sum()
Rank_totals.plot(kind='barh',title = 'average service and phd by rank')
plt.show()

# %%
Rank_totals = df.groupby('rank')[['service','phd']].sum()
Rank_totals.plot(kind='barh',title = 'average service and phd by rank' , color =['red','green'])
plt.show()

# %%
Rank_totals.plot(kind='barh',stacked = True)
# Out:
# <Axes: ylabel='rank'>

# %%
Rank_totals.plot(kind='barh',stacked = True)
plt.title(label = 'total ranked by serivce and phd',loc = 'left')
# Out:
# Text(0.0, 1.0, 'total ranked by serivce and phd')

# %%
Rank_totals.plot(kind='barh',stacked = True)
plt.title(label = 'total ranked by serivce and phd',loc = 'right')
# Out:
# Text(1.0, 1.0, 'total ranked by serivce and phd')

# %%
df[['phd','service']].plot(kind = 'hist',bins = 30,alpha = 0.5)  #bins is only applicabe for histogram #alpha can be applicabe for any chart
#alpha is used for visiblity for both service and phd
# Out:
# <Axes: ylabel='Frequency'>

# %%
df[['phd','service']].plot(kind = 'hist',bins = 30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df[['phd','service']].plot(kind = 'area',alpha = 0.5)
# Out:
# <Axes: >

# %%
df[['phd','service','salary']].plot(kind = 'area',alpha = 0.5)
# Out:
# <Axes: >

# %%
df[['phd','service','salary']].plot(kind = 'area',alpha = 1)
# Out:
# <Axes: >

# %%
df[['phd','salary']].plot(kind = 'area',alpha = 0.5)
# Out:
# <Axes: >

# %%
df.plot(kind = 'box',figsize = (10,6),vert = False)          #vert -> vertical
# Out:
# <Axes: >

# %%
df.plot(kind = 'box',figsize = (10,6),vert = True)
# Out:
# <Axes: >

# %%
df.plot(kind = 'scatter',x = 'service' , y='salary', figsize = (10,6),color = 'yellow')
# Out:
# <Axes: xlabel='service', ylabel='salary'>

# %%
df.plot(kind = 'hexbin',x='service',y='salary',gridsize = 20, figsize=(10,6))
# Out:
# <Axes: xlabel='service', ylabel='salary'>

# %% [markdown]
# Scatter matix plot
# you have already see how to create plot using pandas.
# A scatter matrix, as name suggest, creates a matrix of scatter plot using scatter_matrix methid in pandas.

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df,alpha = 0.5,figsize=(10,6),diagonal = 'kde');

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df,alpha = 0.5,figsize=(10,6),diagonal = 'hist');

# %% [markdown]
# Bootstrap plot
# Bootstrap plots visually assess a statistics uncertainity , such as mean,median,midrange,etc.
# Bootstraping involves calculating a statistics by randomly sampling from the same data multiple times,
# and then average each samples indivisulally result. the resultant values obtained from each random sample are then
# plotted in the form of line and bar charts.

# %%
pd.plotting.bootstrap_plot(df['salary'])

# %% [markdown]
# # ploting using matplotlib.pyplot

# %%
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import matplotlib.pyplot as plt

# %%
#importing mastplotlib module

from matplotlib import pyplot as plt

#x-axis values
x=[5,2,9,4,7]

#y-axis values
y =[6,4,10,9,8]

#function to plot
plt.plot(x,y)

#function to show the plot
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Bar chart

# %%
#importing mastplotlib module

from matplotlib import pyplot as plt

#x-axis values
x=[5,2,9,4,7]

#y-axis values
y =[10,5,8,4,2]

#function to plot
plt.bar(x,y)

#function to show the plot
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Histogram

# %%
#importing mastplotlib module

from matplotlib import pyplot as plt

#x-axis values
x=[5,2,9,4,7]

#y-axis values
y =[10,5,8,4,2]

#function to plot
plt.hist(df['salary'])

#function to show the plot
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#importing mastplotlib module

from matplotlib import pyplot as plt

#x-axis values
x=[5,2,9,4,7]

#y-axis values
y =[10,5,8,4,2]

#function to plot
plt.hist(df['salary'],bins = 5)

#function to show the plot
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#importing mastplotlib module

from matplotlib import pyplot as plt

#x-axis values
x=[5,2,9,4,7]

#y-axis values
y =[10,5,8,4,2]

#function to plot
plt.hist(df['salary'],bins = 5,histtype ='barstacked',orientation = 'horizontal')

#function to show the plot
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#importing mastplotlib module

from matplotlib import pyplot as plt

#x-axis values
x=[5,2,9,4,7]

#y-axis values
y =[10,5,8,4,2]
61
#function to plot
plt.hist(df['salary'],bins = 5,histtype ='barstacked',orientation = 'horizontal',color = 'red')

#function to show the plot
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # scatter plot

# %%
# x,
# y,
# s = None
# c = None
# marker = None
# cmap = None
# norm = None
# vmin = None
# vamx = None
# alpha = None
# linewidth = None
# *
# edgecolors = None
# plotnonfinite = False
# data = None
# **kwards


#importing mastplotlib module

from matplotlib import pyplot as plt

#x-axis values
x=[5,2,9,4,7]

#y-axis values
y =[10,5,8,4,2]

#function to plot
plt.scatter(df['salary'],df['service'])

#function to show the plot
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#importing mastplotlib module

from matplotlib import pyplot as plt

#x-axis values
x=[5,2,9,4,7]

#y-axis values
y =[10,5,8,4,2]

#function to plot
plt.scatter(df['salary'],df['service'],marker = '*')

#function to show the plot
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#importing mastplotlib module

from matplotlib import pyplot as plt

#x-axis values
x=[5,2,9,4,7]

#y-axis values
y =[10,5,8,4,2]

#function to plot
plt.scatter(df['salary'],df['service'],marker = '*',c = 'green')

#function to show the plot
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from matplotlib import pyplot as plt

x=[5,8,10]
y=[12,16,6]

plt.plot(df['salary'])

plt.title('salary Information')
plt.ylabel('value count')
plt.xlabel('salaries in rupees')

plt.show()

# %%
from matplotlib import pyplot as plt
from matplotlib import style

style.use('ggplot')         # ggplot is an library used in R. ggplot gives us backgound grey.

x=[5,8,10]
y=[12,16,6]

x2=[6,9,11]
y2=[6,15,7]


plt.plot(x,y,linewidth = 10)
plt.scatter(x2,y2,linewidth=5)

plt.title('Epic Info')
plt.ylabel('Y axis')
plt.xlabel('X axis')

plt.show()

# %%
from matplotlib import pyplot as plt
from matplotlib import style

style.use('ggplot')

x=[5,8,10]
y=[12,16,6]

x2=[6,9,11]
y2=[6,15,7]


plt.plot(x,y,'g',label='line one',linewidth=5)
plt.plot(x2,y2,'c',label='line two',linewidth=5)

plt.title('Epic Info')
plt.ylabel('Y axis')
plt.xlabel('X axis')

plt.legend()

plt.grid(True,color = 'k')          #here k meant for black color grid lines.

plt.show()

# %% [markdown]
# # Bar plot

# %%
from matplotlib import pyplot as plt
from matplotlib import style

style.use('ggplot')

x = [5,8,10]
y = [12,16,6]

x2 = [6,9,11]
y2 = [6,15,7]

plt.bar(x,y, align = 'center')

plt.bar(x2,y2, color = 'g', align = 'center')

plt.title('Epic Info')
plt.ylabel('Y axis')
plt.xlabel('X axis')

plt.show()

# %%
from matplotlib import pyplot as plt
from matplotlib import style

style.use('ggplot')

x = [5,8,10]
y = [12,16,6]

x2 = [6,9,11]
y2 = [6,15,7]

plt.scatter(x,y)

plt.scatter(x2,y2, color = 'g')

plt.title('Epic Info')
plt.ylabel('Y axis')
plt.xlabel('X axis')

plt.show()

# %%
from matplotlib import pyplot as plt
from matplotlib import style

style.use('ggplot')

x = [5,8,10]
y = [12,16,6]

x2 = [6,9,11]
y2 = [6,15,7]

plt.scatter(x,y)

plt.bar(x2,y2, color = 'g')

plt.title('Epic Info')
plt.ylabel('Y axis')
plt.xlabel('X axis')

plt.show()

# %% [markdown]
# figure class
# Figure class is the top level container that contains one or more axes.
# It is the overall window or page on which everything is drawn.
#
# Syntax:
#
# class matplotlib.figure.Figure(figsize=None, dpi=None, facecolor=None, edgecolor=None, linewidth=0.0,
#                               frameon=None, subploter=None, tight_layout=None, constrained_layout=None)

# %%
# Python program to show pyplot module
import matplotlib.pyplot as plt 
from matplotlib.figure import Figure 
  
# Creating a new figure with width = 5 inches
# and height = 4 inches
fig = plt.figure(figsize =(5, 4))   #if figsize is notgiven is is come as bydeafult.
  
# Creating a new axes for the figure
ax = fig.add_axes([1, 1, 1, 1]) 
  
# Adding the data to be plotted
ax.plot([2, 3, 4, 5, 5, 6, 6],
        [5, 7, 1, 3, 4, 6 ,8])
plt.show()

# %%
# Python program to show pyplot module
import matplotlib.pyplot as plt 
from matplotlib.figure import Figure 
  
# Creating a new figure with width = 5 inches
# and height = 4 inches
fig = plt.figure(figsize =(5, 4)) 
  
# Creating a new axes for the figure
ax = fig.add_axes([2, 2, 2, 2]) 
  
# Adding the data to be plotted
ax.plot([2, 3, 4, 5, 5, 6, 6],
        [5, 7, 1, 3, 4, 6 ,8])
plt.show()

# %%
# Python program to show pyplot module
import matplotlib.pyplot as plt 
from matplotlib.figure import Figure 
  
# Creating a new figure with width = 5 inches
# and height = 4 inches
fig = plt.figure(figsize =(5, 4)) 
  
# Creating first axes for the figure
ax1 = fig.add_axes([1, 1, 1, 1]) 
  
# Creating second axes for the figure
ax2 = fig.add_axes([1, 0.5, 0.5, 0.5])
  
# Adding the data to be plotted
ax1.plot([2, 3, 4, 5, 5, 6, 6], 
         [5, 7, 1, 3, 4, 6 ,8])
ax2.plot([1, 2, 3, 4, 5], 
         [2, 3, 4, 5, 6])
  
plt.show()

# %% [markdown]
# Axes Class
# Axes class is the most basic and flexible unit for creating sub-plots.
# A given figure may contain many axes, but a given axes can only be present in one figure.
# The axes() function creates the axes object. Let’s see the below example.
#
# Syntax:
#
# matplotlib.pyplot.axes(*args, emit=True, **kwargs)

# %%
# Python program to show pyplot module
import matplotlib.pyplot as plt 
from matplotlib.figure import Figure 
# Creating the axes object with argument as 
# [left, bottom, width, height]
ax = plt.axes([1, 1, 1, 1])

# %%
# Python program to show pyplot module
import matplotlib.pyplot as plt 
from matplotlib.figure import Figure 
# Creating the axes object with argument as 
# [left, bottom, width, height]
ax = plt.axes([1, 1, 1, 1],projection = 'hammer')

# %%
# Python program to show pyplot module
import matplotlib.pyplot as plt 
from matplotlib.figure import Figure 
# Creating the axes object with argument as 
# [left, bottom, width, height]
#aitoff , hammer , Lambert , mollweide , polar , rectilinear
ax = plt.axes([1, 1, 1, 1],projection = 'aitoff',polar=False)

# %%
# Python program to show pyplot module
import matplotlib.pyplot as plt 
from matplotlib.figure import Figure 
# Creating the axes object with argument as 
# [left, bottom, width, height]
ax = plt.axes([1, 1, 1, 1],projection = 'lambert')

# %%
# Python program to show pyplot module
import matplotlib.pyplot as plt 
from matplotlib.figure import Figure 
x = [3, 1, 3] 
y = [3, 2, 1] 
  
# Creating a new figure with width = 5 inches
# and height = 4 inches
fig = plt.figure(figsize =(5, 4)) 
  
# Creating first axes for the figure
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8]) 
  
# Adding the data to be plotted
ax.plot(x, y)
ax.set_xlim(1, 2)
ax.set_xticklabels((
    "one", "two", "three", "four", "five", "six")) 
plt.show()
# Out:
# C:\Users\Anish\AppData\Local\Temp\ipykernel_8872\990124429.py:17: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels((

# %%
# Python program to show pyplot module
import matplotlib.pyplot as plt 
from matplotlib.figure import Figure 
  
# Creating a new figure with width = 5 inches
# and height = 4 inches
fig = plt.figure(figsize =(5, 4)) 
  
# Creating first axes for the figure
ax1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) 
  
# Creating second axes for the figure
ax2 = fig.add_axes([0.5, 0.5, 0.3, 0.3])
  
# Adding the data to be plotted
ax1.plot([5, 4, 3, 2, 1], [2, 3, 4, 5, 6])
ax2.plot([1, 2, 3, 4, 5], [2, 3, 4, 5, 6])
plt.show()

# %%
import matplotlib.pyplot as plt 
# data to display on plots 
x = [3, 1, 3] 
y = [3, 2, 1] 
z = [1, 3, 1] 
  
# Creating figure object 
plt.figure() 
  
# adding first subplot 
plt.subplot(121) 
plt.plot(x, y) 
  
# adding second subplot 
plt.subplot(122) 
plt.plot(z, y)

# %%
import matplotlib.pyplot as plt 
# data to display on plots 
x = [3, 1, 3] 
y = [3, 2, 1] 
z = [1, 3, 1] 
  
# Creating figure object 
plt.figure() 
  
# adding first subplot 
plt.subplot(121) 
plt.scatter(x, y) 
  
# adding second subplot 
plt.subplot(122) 
plt.plot(z, y)

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt 
# Creating the figure object
fig = plt.figure()
  
# keeping the projection = 3d
# creates the 3d plot
ax = plt.axes(projection = '3d')

# %%
import matplotlib.pyplot as plt 
x = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 25]
z = [1, 8, 27, 64, 125]
# Creating the figure object
fig = plt.figure()
# keeping the projection = 3d
# creates the 3d plot
ax = plt.axes(projection = '3d')
ax.plot3D(z, y, x)

# %% [markdown]
# Seaborn Plot types

# %% [markdown]
# Univariate – x only (contains only one axis of information)
# Bivariate – x and y (contains two axis of information)
# Trivariate – x, y, z (contains three axis of information)
#
# Scatter Plot. A scatter plot is used to visualize the relationship between two variables.
# Seaborn's scatterplot() function provides a simple way to create scatter plots.
#
# Line Plot. A line plot is used to visualize the trend of a variable over time.
# Seaborn's lineplot() function provides a simple way to create line plots.
#
# Histogram. A histogram is used to visualize the distribution of a variable.
# Seaborn's histplot() function provides a simple way to create histograms.
#
# Box Plot. A box plot is used to visualize the distribution of a variable.
# Seaborn's boxplot() function provides a simple way to create box plots.
#
# Violin Plot. A violin plot is similar to a box plot, but provides a more detailed view of the distribution of the data.
# Seaborn's violinplot() function provides a simple way to create violin plots.
#
# Heatmap. A heatmap is used to visualize the correlation between different variables.
# Seaborn's heatmap() function provides a simple way to create heatmaps.
#
# Pairplot. A pairplot is used to visualize the relationship between multiple variables.
# Seaborn's pairplot() function provides a simple way to create pairplots.

# %%
import seaborn as sns




# Load the Tips dataset

tips = sns.load_dataset("tips")    #here tips is persent in this library from github.


# Create a histogram of the total bill amounts

sns.histplot(data=tips, x="total_bill")
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %% [markdown]
# # Seaborn scatter plot

# %%
import seaborn as sns

tips = sns.load_dataset("tips")

sns.scatterplot(x="total_bill", y="tip", data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
import seaborn as sns

import matplotlib.pyplot as plt


tips = sns.load_dataset("tips")


# customize the scatter plot

sns.scatterplot(x="total_bill", y="tip", hue="sex", size="size", sizes=(50, 200), data=tips)  #size here is an column in the tips


# add labels and title

plt.xlabel("Total Bill")

plt.ylabel("Tip")

plt.title("Relationship between Total Bill and Tip")


# display the plot

plt.show()

# %% [markdown]
# # Seaborn line plots

# %%
import seaborn as sns

fmri = sns.load_dataset("fmri")

sns.lineplot(x="timepoint", y="signal", data=fmri)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
import seaborn as sns

import matplotlib.pyplot as plt


fmri = sns.load_dataset("fmri")


# customize the line plot

sns.lineplot(x="timepoint", y="signal", hue="event", style="region", markers=True, dashes=False, data=fmri)


# add labels and title

plt.xlabel("Timepoint")

plt.ylabel("Signal Intensity")

plt.title("Changes in Signal Intensity over Time")


# display the plot

plt.show()

# %% [markdown]
# # Seaborn bar plots

# %%
import seaborn as sns

titanic = sns.load_dataset("titanic")

sns.barplot(x="class", y="fare", data=titanic)
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
import seaborn as sns

import matplotlib.pyplot as plt


titanic = sns.load_dataset("titanic")


# customize the bar plot

sns.barplot(x="class", y="fare", hue="sex", ci=None, palette="muted", data=titanic)



# add labels and title

plt.xlabel("Class")

plt.ylabel("Fare")

plt.title("Average Fare by Class and Gender on the Titanic")


# display the plot

plt.show()
# Out:
# C:\Users\Anish\AppData\Local\Temp\ipykernel_1948\3904464276.py:11: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="class", y="fare", hue="sex", ci=None, palette="muted", data=titanic)

# %%
import seaborn as sns

iris = sns.load_dataset("iris")

sns.histplot(x="petal_length", data=iris)
# Out:
# <Axes: xlabel='petal_length', ylabel='Count'>

# %%
import seaborn as sns

import matplotlib.pyplot as plt


iris = sns.load_dataset("iris")


# customize the histogram

sns.histplot(data=iris, x="petal_length", bins=20, kde=True, color="green")


# add labels and title

plt.xlabel("Petal Length (cm)")

plt.ylabel("Frequency")

plt.title("Distribution of Petal Lengths in Iris Flowers")



# display the plot

plt.show()

# %% [markdown]
# # Seaborn density plots

# %%
import seaborn as sns

tips = sns.load_dataset("tips")

sns.kdeplot(data=tips, x="total_bill")
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
import pandas as pd
tips['tip'].kurt()            #mesokurtic
# Out:
# 3.648375873352852

# %% [markdown]
# # Seaborn boxplot

# %%
import seaborn as sns

import matplotlib.pyplot as plt


# load the tips dataset from Seaborn

tips = sns.load_dataset("tips")


# create a box plot of total bill by day and meal time, using the "hue" parameter to differentiate between lunch and dinner

# customize the color scheme using the "palette" parameter

# adjust the linewidth and fliersize parameters to make the plot more visually appealing

sns.boxplot(x="day", y="total_bill", hue="time", data=tips, palette="Set3", linewidth=1.5, fliersize=4)



# add a title, xlabel, and ylabel to the plot using Matplotlib functions

plt.title("Box Plot of Total Bill by Day and Meal Time")

plt.xlabel("Day of the Week")

plt.ylabel("Total Bill ($)")


# display the plot

plt.show()

# %% [markdown]
# # Seaborn violin plots

# %%
import seaborn as sns         #inside it is boxplot. it is similar to boxplot.


# load the iris dataset from Seaborn

iris = sns.load_dataset("iris")


# create a violin plot of petal length by species

sns.violinplot(x="species", y="petal_length", data=iris)



# display the plot

plt.show()

# %% [markdown]
# # Seaborn heatmaps

# %%
import seaborn as sns
import matplotlib.pyplot as plt     #heat map is all about how much data has been relation.

# Load the dataset

flights = sns.load_dataset('flights')


# Pivot the data

flights = flights.pivot('month', 'year', 'passengers')


# Create a heatmap

sns.heatmap(flights, cmap='Blues', annot=True, fmt='d')       #cmap stands for colormap. #annot is the annotation.
                                                              #fmt is the formating of the annnotation.
                      #if the their is the darker color that means there is a higher relation to that variable.
# Set the title and axis labels                           

plt.title('Passengers per month')

plt.xlabel('Year')
plt.ylabel('Month')


# Show the plot

plt.show()
# Out:
# C:\Users\Anish\AppData\Local\Temp\ipykernel_1948\3351141411.py:17: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   flights = flights.pivot('month', 'year', 'passengers')

# %% [markdown]
# # Seaborn pair plots

# %%
import seaborn as sns


# Load iris dataset

iris = sns.load_dataset("iris")


# Create pair plot

sns.pairplot(data=iris)


# Show plot

plt.show()

# %%
import seaborn as sns

import matplotlib.pyplot as plt




# Load iris dataset

iris = sns.load_dataset("iris")




# Create pair plot with custom settings

sns.pairplot(data=iris, hue="species", diag_kind="kde", palette="husl")




# Set title

plt.title("Iris Dataset Pair Plot")




# Show plot

plt.show()

# %% [markdown]
# # Seaborn joint plots

# %%
import seaborn as sns

import matplotlib.pyplot as plt




# load iris dataset

iris = sns.load_dataset("iris")




# plot a joint plot of sepal length and sepal width

sns.jointplot(x="sepal_length", y="sepal_width", data=iris)




# display the plot

plt.show()

# %% [markdown]
# # Seaborn facet grids

# %%
import seaborn as sns




# load the tips dataset

tips = sns.load_dataset('tips')




# create a FacetGrid for day vs total_bill

g = sns.FacetGrid(tips, col="day")




# plot histogram for total_bill in each day

g.map(sns.histplot, "total_bill")

# %% [markdown]
# Customizing Seaborn plots
#
# Changing Color Palettes
#
# Adjusting Figure Size
#
# Adding Annotations

# %%
import seaborn as sns

import matplotlib.pyplot as plt




# Load sample dataset

tips = sns.load_dataset("tips")




# Create a scatter plot with color palette

sns.scatterplot(x="total_bill", y="tip", hue="day", data=tips, palette="Set2")




# Customize plot

plt.title("Total Bill vs Tip")

plt.xlabel("Total Bill ($)")

plt.ylabel("Tip ($)")

plt.show()

# %%
import seaborn as sns

import matplotlib.pyplot as plt




# Load sample dataset

diamonds = sns.load_dataset("diamonds")




# Create a scatter plot with annotations

sns.scatterplot(x="carat", y="price", data=diamonds)




# Add annotations

plt.text(1, 18000, "Large, Expensive Diamonds", fontsize=12, color="red")

plt.text(2.5, 5000, "Small, Affordable Diamonds", fontsize=12, color="blue")



# Customize plot

plt.title("Diamond Prices by Carat")

plt.xlabel("Carat (ct)")

plt.ylabel("Price ($)")

plt.show()
